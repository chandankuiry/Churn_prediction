# %%
#so here I have done same thing upto In[210] as churn_prediction.ipynb .So check after ln ln[210]
import pickle
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import pandas as pd
import numpy as np
import csv
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
df = pd.read_csv('Churn_dataset.csv')

# %%
df.head(50)
# Out:
#       ID       DOB Plan  LastMonthlyBill  LastpaidAmount  Occupation  \
# 0     19  29/12/74    B               41              20         NaN
# 1     88   11/1/23    B               32              20         NaN
# 2    130    3/1/54    D               60              20         NaN
# 3    227   12/1/20    F               37              20    Business
# 4    294  26/12/84    F               66              20  Government
# 5    394    2/1/58    D               50              20          IT
# 6    423  26/12/85    D               56              20     Medical
# 7    438    8/1/34    F              101              20     Finance
# 8    669  24/12/94    F              132              20       Sales
# 9    726    8/1/34    D               81              20          IT
# 10   844    4/1/52    E               31              20       Sales
# 11   897    3/1/56    F              129              20     Medical
# 12   907  27/12/82    E               39              20    Business
# 13   919  22/12/02    A               94              20          IT
# 14   990    4/1/50    D               52              20  Government
# 15  1000  26/12/85    B               45              20     Finance
# 16  1007  29/12/75    A               41              20    Engineer
# 17  1055   11/1/23    D               36              20       Sales
# 18  1179  27/12/80    D               36              20     Medical
# 19  1265    8/1/36    C               36              20     Medical
# 20  1289  23/12/97    C               42              20      Others
# 21  1321  26/12/84    E               30              20  Government
# 22  1332  24/12/95    E              128              20  Government
# 23  1357   11/1/22    A              126              20    Engineer
# 24  1366   11/1/21    D               36              20       Sales
# 25  1369  26/12/84    A              126              20          IT
# 26  1399   11/1/22    F              109              20     Medical
# 27  1409  30/12/69    D               47              20    Engineer
# 28  1439  30/12/69    A               96              20     Finance
# 29  1459   11/1/22    F               30              20       Sales
# 30  1521  28/12/78    C               89              20    Business
# 31  1526  26/12/85    E               35              20     Finance
# 32  1536    2/1/60    E               87              20     Medical
# 33  1550   10/1/26    D               34              20      Others
# 34  1596    4/1/51    D               36              20      Others
# 35  1653   11/1/22    D               77              20       Sales
# 36  1781   10/1/28    D               31              20     Medical
# 37  1800    6/1/42    B               60              20      Others
# 38  1816    7/1/38    B               50              20     Finance
# 39  1856    1/1/64    A               60              20      Others
# 40  1916   11/1/24    F               42              20     Finance
# 41  1949    2/1/59    B               32              20     Finance
# 42  1997    6/1/43    C               45              20      Others
# 43  2077    3/1/56    D              119              20      Others
# 44  2202    2/1/58    F              125              20  Government
# 45  2223   11/1/24    B               33              20    Business
# 46  2243    3/1/55    D               94              20          IT
# 47  2261  22/12/01    B               37              20          IT
# 48  2424  28/12/77    A               31              20     Finance
# 49  2440  30/12/71    F               35              20      Others
#
#    IncomeLevel Gender SubscriberJoinDate  \
# 0          Low      M            15/1/17
# 1         High      M            15/1/17
# 2       Medium      F            30/7/14
# 3          Low      M            3/10/13
# 4         High      F            21/3/16
# 5       Medium      M            30/7/14
# 6          Low      M            21/3/16
# 7       Medium      F            3/10/13
# 8          Low      F            26/5/15
# 9          Low      F            21/3/16
# 10      Medium      M            26/5/15
# 11         Low      M            30/7/14
# 12        High      M            3/10/13
# 13         Low      M            3/10/13
# 14        High      M            26/5/15
# 15         Low      M            3/10/13
# 16        High      M            30/7/14
# 17      Medium      M            15/1/17
# 18      Medium      F            26/5/15
# 19         Low      M            30/7/14
# 20      Medium      M            30/7/14
# 21        High      F            21/3/16
# 22      Medium      M            15/1/17
# 23        High      M            3/10/13
# 24         Low      M            30/7/14
# 25      Medium      M            26/5/15
# 26         Low      M            15/1/17
# 27         Low      M            30/7/14
# 28        High    NaN            30/7/14
# 29      Medium      M            30/7/14
# 30      Medium      F            21/3/16
# 31         Low      M            30/7/14
# 32         Low      F            21/3/16
# 33         Low      M            3/10/13
# 34         Low      M            15/1/17
# 35         Low      M            15/1/17
# 36         Low      F            15/1/17
# 37      Medium      M            3/10/13
# 38         Low      F            30/7/14
# 39      Medium      M            3/10/13
# 40        High      F            3/10/13
# 41      Medium      F            3/10/13
# 42        High      F            21/3/16
# 43         Low      F            26/5/15
# 44        High      M            30/7/14
# 45        High      F            21/3/16
# 46        High      M            26/5/15
# 47      Medium      M            30/7/14
# 48      Medium      F            21/3/16
# 49         Low      M            15/1/17
#
#     LastSatisfactionSurveyScore(1=V.Poor, 5=V.High) Churn
# 0                                                 1    No
# 1                                                 4    No
# 2                                                 5    No
# 3                                                 1    No
# 4                                                 2    No
# 5                                                 3    No
# 6                                                 1    No
# 7                                                 4    No
# 8                                                 4    No
# 9                                                 5    No
# 10                                                5    No
# 11                                                2    No
# 12                                                4    No
# 13                                                1    No
# 14                                                3    No
# 15                                                5    No
# 16                                                4    No
# 17                                                5    No
# 18                                                4    No
# 19                                                1    No
# 20                                                2    No
# 21                                                3    No
# 22                                                3    No
# 23                                                1    No
# 24                                                4    No
# 25                                                5    No
# 26                                                3    No
# 27                                                2    No
# 28                                                4    No
# 29                                                2    No
# 30                                                3    No
# 31                                                4    No
# 32                                                2    No
# 33                                                5    No
# 34                                                3    No
# 35                                                1    No
# 36                                                1    No
# 37                                                4    No
# 38                                                2    No
# 39                                                3    No
# 40                                                5    No
# 41                                                2    No
# 42                                                2    No
# 43                                                3    No
# 44                                                2    No
# 45                                                5   Yes
# 46                                                1    No
# 47                                                3    No
# 48                                                3    No
# 49                                                3    No

# %%
df.shape
# Out:
# (9789, 11)

# %%
print("Number of rows: ", df.shape[0])
counts = df.describe().iloc[0]
display(
    pd.DataFrame(
        counts.tolist(), 
        columns=["Count of values"], 
        index=counts.index.values
    ).transpose()
)
# Out:
# ('Number of rows: ', 9789)
#                      ID  LastMonthlyBill  LastpaidAmount  \
# Count of values  9789.0           9789.0          9789.0
#
#                  LastSatisfactionSurveyScore(1=V.Poor, 5=V.High)
# Count of values                                           9789.0

# %%
df2 = pd.DataFrame(df["Plan"]) #  Interim DF only - Attr
names1 = df2.columns.values
print names1
print df2.shape 
print df2["Plan"].value_counts()
# Out:
# ['Plan']
# (9789, 1)
# A    1702
# E    1663
# D    1616
# C    1611
# F    1599
# B    1598
# Name: Plan, dtype: int64

# %%
df2 = pd.DataFrame(df["Occupation"]) 
names1 = df2.columns.values
print names1
print df2.shape 
print df2["Occupation"].value_counts()
# Out:
# ['Occupation']
# (9789, 1)
# IT            1286
# Sales         1250
# Engineer      1210
# Government    1205
# Others        1193
# Medical       1191
# Finance       1139
# Business      1111
# Name: Occupation, dtype: int64

# %%
#to know the score are given and the occurence 
df2 = pd.DataFrame(df["LastSatisfactionSurveyScore(1=V.Poor, 5=V.High)"]) 
names1 = df2.columns.values
print names1
print df2.shape 
print df2["LastSatisfactionSurveyScore(1=V.Poor, 5=V.High)"].value_counts()
# Out:
# ['LastSatisfactionSurveyScore(1=V.Poor, 5=V.High)']
# (9789, 1)
# 5    1992
# 4    1975
# 1    1942
# 2    1941
# 3    1939
# Name: LastSatisfactionSurveyScore(1=V.Poor, 5=V.High), dtype: int64

# %%
#to how many yes and NO are there
df2 = pd.DataFrame(df["Churn"]) 
names1 = df2.columns.values
print names1
print df2.shape 
print df2["Churn"].value_counts()
# Out:
# ['Churn']
# (9789, 1)
# No     8208
# Yes    1521
# NO       60
# Name: Churn, dtype: int64

# %%
df2 = pd.DataFrame(df["SubscriberJoinDate"]) #  Interim DF only - Attr
names1 = df2.columns.values
print names1
print df2.shape 
print df2["SubscriberJoinDate"].value_counts()
# Out:
# ['SubscriberJoinDate']
# (9789, 1)
# 15/1/17    2035
# 30/7/14    1984
# 21/3/16    1980
# 3/10/13    1923
# 26/5/15    1867
# Name: SubscriberJoinDate, dtype: int64

# %%
#now we can conver this feature as number like 
mymap = {'Yes':1,'No':0,'NO':0,' ':0,'IT':8,'Sales':7,'Engineer':6,'Government':5,'Others':4,'Medical':3,'Finance':2,'Business':1,
         'A':6,'E':5,'D':4,'C':3,'F':2,'B':1,'M':1,'Low':1,'Medium':2,'High':3,'15/1/17':11,'30/7/14':40,'21/3/16':20,
         '3/10/13':50,'26/5/15':30}#male=,female:2 and subscriber joining date according to month like '15/1/17':11 

df1 =df.applymap(lambda s: mymap.get(s) if s in mymap else s)
df1['ID'].fillna(0, inplace=True)
df1['DOB'].fillna(0, inplace=True)
df1['Plan'].fillna(0, inplace=True)
df1['Occupation'].fillna(0, inplace=True)
df1['LastMonthlyBill'].fillna(0, inplace=True)
df1['Plan'].fillna(0, inplace=True)
df1['LastpaidAmount'].fillna(0, inplace=True)
df1['IncomeLevel'].fillna(0, inplace=True)
df1['Gender'].fillna(0, inplace=True)
df1['SubscriberJoinDate'].fillna(0, inplace=True)
df1['LastSatisfactionSurveyScore(1=V.Poor, 5=V.High)'].fillna(0, inplace=True)
df1['Churn'].fillna(0, inplace=True)
df1.head(50)
# Out:
#       ID       DOB  Plan  LastMonthlyBill  LastpaidAmount  Occupation  \
# 0     19  29/12/74     1               41              20         0.0
# 1     88   11/1/23     1               32              20         0.0
# 2    130    3/1/54     4               60              20         0.0
# 3    227   12/1/20     2               37              20         1.0
# 4    294  26/12/84     2               66              20         5.0
# 5    394    2/1/58     4               50              20         8.0
# 6    423  26/12/85     4               56              20         3.0
# 7    438    8/1/34     2              101              20         2.0
# 8    669  24/12/94     2              132              20         7.0
# 9    726    8/1/34     4               81              20         8.0
# 10   844    4/1/52     5               31              20         7.0
# 11   897    3/1/56     2              129              20         3.0
# 12   907  27/12/82     5               39              20         1.0
# 13   919  22/12/02     6               94              20         8.0
# 14   990    4/1/50     4               52              20         5.0
# 15  1000  26/12/85     1               45              20         2.0
# 16  1007  29/12/75     6               41              20         6.0
# 17  1055   11/1/23     4               36              20         7.0
# 18  1179  27/12/80     4               36              20         3.0
# 19  1265    8/1/36     3               36              20         3.0
# 20  1289  23/12/97     3               42              20         4.0
# 21  1321  26/12/84     5               30              20         5.0
# 22  1332  24/12/95     5              128              20         5.0
# 23  1357   11/1/22     6              126              20         6.0
# 24  1366   11/1/21     4               36              20         7.0
# 25  1369  26/12/84     6              126              20         8.0
# 26  1399   11/1/22     2              109              20         3.0
# 27  1409  30/12/69     4               47              20         6.0
# 28  1439  30/12/69     6               96              20         2.0
# 29  1459   11/1/22     2               30              20         7.0
# 30  1521  28/12/78     3               89              20         1.0
# 31  1526  26/12/85     5               35              20         2.0
# 32  1536    2/1/60     5               87              20         3.0
# 33  1550   10/1/26     4               34              20         4.0
# 34  1596    4/1/51     4               36              20         4.0
# 35  1653   11/1/22     4               77              20         7.0
# 36  1781   10/1/28     4               31              20         3.0
# 37  1800    6/1/42     1               60              20         4.0
# 38  1816    7/1/38     1               50              20         2.0
# 39  1856    1/1/64     6               60              20         4.0
# 40  1916   11/1/24     2               42              20         2.0
# 41  1949    2/1/59     1               32              20         2.0
# 42  1997    6/1/43     3               45              20         4.0
# 43  2077    3/1/56     4              119              20         4.0
# 44  2202    2/1/58     2              125              20         5.0
# 45  2223   11/1/24     1               33              20         1.0
# 46  2243    3/1/55     4               94              20         8.0
# 47  2261  22/12/01     1               37              20         8.0
# 48  2424  28/12/77     6               31              20         2.0
# 49  2440  30/12/71     2               35              20         4.0
#
#     IncomeLevel  Gender  SubscriberJoinDate  \
# 0           1.0     1.0                  11
# 1           3.0     1.0                  11
# 2           2.0     2.0                  40
# 3           1.0     1.0                  50
# 4           3.0     2.0                  20
# 5           2.0     1.0                  40
# 6           1.0     1.0                  20
# 7           2.0     2.0                  50
# 8           1.0     2.0                  30
# 9           1.0     2.0                  20
# 10          2.0     1.0                  30
# 11          1.0     1.0                  40
# 12          3.0     1.0                  50
# 13          1.0     1.0                  50
# 14          3.0     1.0                  30
# 15          1.0     1.0                  50
# 16          3.0     1.0                  40
# 17          2.0     1.0                  11
# 18          2.0     2.0                  30
# 19          1.0     1.0                  40
# 20          2.0     1.0                  40
# 21          3.0     2.0                  20
# 22          2.0     1.0                  11
# 23          3.0     1.0                  50
# 24          1.0     1.0                  40
# 25          2.0     1.0                  30
# 26          1.0     1.0                  11
# 27          1.0     1.0                  40
# 28          3.0     0.0                  40
# 29          2.0     1.0                  40
# 30          2.0     2.0                  20
# 31          1.0     1.0                  40
# 32          1.0     2.0                  20
# 33          1.0     1.0                  50
# 34          1.0     1.0                  11
# 35          1.0     1.0                  11
# 36          1.0     2.0                  11
# 37          2.0     1.0                  50
# 38          1.0     2.0                  40
# 39          2.0     1.0                  50
# 40          3.0     2.0                  50
# 41          2.0     2.0                  50
# 42          3.0     2.0                  20
# 43          1.0     2.0                  30
# 44          3.0     1.0                  40
# 45          3.0     2.0                  20
# 46          3.0     1.0                  30
# 47          2.0     1.0                  40
# 48          2.0     2.0                  20
# 49          1.0     1.0                  11
#
#     LastSatisfactionSurveyScore(1=V.Poor, 5=V.High)  Churn
# 0                                                 1      0
# 1                                                 4      0
# 2                                                 5      0
# 3                                                 1      0
# 4                                                 2      0
# 5                                                 3      0
# 6                                                 1      0
# 7                                                 4      0
# 8                                                 4      0
# 9                                                 5      0
# 10                                                5      0
# 11                                                2      0
# 12                                                4      0
# 13                                                1      0
# 14                                                3      0
# 15                                                5      0
# 16                                                4      0
# 17                                                5      0
# 18                                                4      0
# 19                                                1      0
# 20                                                2      0
# 21                                                3      0
# 22                                                3      0
# 23                                                1      0
# 24                                                4      0
# 25                                                5      0
# 26                                                3      0
# 27                                                2      0
# 28                                                4      0
# 29                                                2      0
# 30                                                3      0
# 31                                                4      0
# 32                                                2      0
# 33                                                5      0
# 34                                                3      0
# 35                                                1      0
# 36                                                1      0
# 37                                                4      0
# 38                                                2      0
# 39                                                3      0
# 40                                                5      0
# 41                                                2      0
# 42                                                2      0
# 43                                                3      0
# 44                                                2      0
# 45                                                5      1
# 46                                                1      0
# 47                                                3      0
# 48                                                3      0
# 49                                                3      0

# %%
#now we conver DOB to age and rename the column dob to age and also rename the LastSatisfactionSurveyScore(1=V.Poor, 5=V.High) 
mymap = {'22/12/01':16 ,'6/1/43':75 ,'6/1/44':74 ,'29/12/74':43,'30/12/69':48,'12/1/18':100 ,
         '11/1/24':94,'24/12/92' :25 ,'30/12/70':47,'2/1/60':58 ,'4/1/49':69 ,'1/1/62':56,'6/1/42': 76,'29/12/72':45,
          '26/12/84':33,'5/1/48':68,
         '27/12/80':37,'12/1/19': 99,'24/12/94' :23,'6/1/41':77, '11/1/21':97,'3/1/53':65,'7/1/37':81,'31/12/67':50,
         '2/1/59':59,'25/12/90':27,'10/1/26' :92,'11/1/23':95,'9/1/31':87,'3/1/55':63,'26/12/87': 30,'5/1/45':73,
         '3/1/54':64,'26/12/85':32, '8/1/34':84,'3/1/56':62,'27/12/82':35,'22/12/02':15,'29/12/75':42,'8/1/36':82,
         '10/1/25':93,'7/1/38':80,'24/12/93':24,'25/12/91':26,'9/1/32':86,'1/1/63':55,'26/12/86':31,'10/1/27':91,'10/1/27':91,
         '5/1/47':71,'31/12/66':51,'4/1/52':66,'4/1/51':67,'9/1/29':89,'8/1/33':85,'8/1/35':83,        
         '2/1/58':60,'24/12/95':22, '28/12/79':38,'7/1/39':79 ,'25/12/89':28, '22/12/00':17,'23/12/98':19,'2/1/57':61,  
         '23/12/97':20, '31/12/65':52, '1/1/61':57,'27/12/83':34,'31/12/64':53,'23/12/99':18, '7/1/40':78,
         '9/1/30':88,        
         '1/1/64':54,        
         '5/1/46':72,        
         '30/12/68':49,      
         '28/12/78':39,      
         '29/12/73':44,      
         '11/1/22':96,       
         '23/12/96':21,      
         '10/1/28':90,        
         '4/1/50':68,         
         '12/1/20':98,        
         '30/12/71':46,       
         '28/12/77':40,       
         '28/12/76':39,       
         '25/12/88':29,       
         '27/12/81':36,       
         '27/12/18':99,        
         '31/12/17':100,        
         '12/1/1875':143,       
         '30/12/1869': 148} 

df1 =df1.applymap(lambda s: mymap.get(s) if s in mymap else s)
df1=df1.rename(index=str, columns={'DOB':'AGE','LastSatisfactionSurveyScore(1=V.Poor, 5=V.High)':'LastSatisfactionSurveyScore'})
#
df1.head(50)
# Out:
#       ID  AGE  Plan  LastMonthlyBill  LastpaidAmount  Occupation  IncomeLevel  \
# 0     19   43     1               41              20         0.0          1.0
# 1     88   95     1               32              20         0.0          3.0
# 2    130   64     4               60              20         0.0          2.0
# 3    227   98     2               37              20         1.0          1.0
# 4    294   33     2               66              20         5.0          3.0
# 5    394   60     4               50              20         8.0          2.0
# 6    423   32     4               56              20         3.0          1.0
# 7    438   84     2              101              20         2.0          2.0
# 8    669   23     2              132              20         7.0          1.0
# 9    726   84     4               81              20         8.0          1.0
# 10   844   66     5               31              20         7.0          2.0
# 11   897   62     2              129              20         3.0          1.0
# 12   907   35     5               39              20         1.0          3.0
# 13   919   15     6               94              20         8.0          1.0
# 14   990   68     4               52              20         5.0          3.0
# 15  1000   32     1               45              20         2.0          1.0
# 16  1007   42     6               41              20         6.0          3.0
# 17  1055   95     4               36              20         7.0          2.0
# 18  1179   37     4               36              20         3.0          2.0
# 19  1265   82     3               36              20         3.0          1.0
# 20  1289   20     3               42              20         4.0          2.0
# 21  1321   33     5               30              20         5.0          3.0
# 22  1332   22     5              128              20         5.0          2.0
# 23  1357   96     6              126              20         6.0          3.0
# 24  1366   97     4               36              20         7.0          1.0
# 25  1369   33     6              126              20         8.0          2.0
# 26  1399   96     2              109              20         3.0          1.0
# 27  1409   48     4               47              20         6.0          1.0
# 28  1439   48     6               96              20         2.0          3.0
# 29  1459   96     2               30              20         7.0          2.0
# 30  1521   39     3               89              20         1.0          2.0
# 31  1526   32     5               35              20         2.0          1.0
# 32  1536   58     5               87              20         3.0          1.0
# 33  1550   92     4               34              20         4.0          1.0
# 34  1596   67     4               36              20         4.0          1.0
# 35  1653   96     4               77              20         7.0          1.0
# 36  1781   90     4               31              20         3.0          1.0
# 37  1800   76     1               60              20         4.0          2.0
# 38  1816   80     1               50              20         2.0          1.0
# 39  1856   54     6               60              20         4.0          2.0
# 40  1916   94     2               42              20         2.0          3.0
# 41  1949   59     1               32              20         2.0          2.0
# 42  1997   75     3               45              20         4.0          3.0
# 43  2077   62     4              119              20         4.0          1.0
# 44  2202   60     2              125              20         5.0          3.0
# 45  2223   94     1               33              20         1.0          3.0
# 46  2243   63     4               94              20         8.0          3.0
# 47  2261   16     1               37              20         8.0          2.0
# 48  2424   40     6               31              20         2.0          2.0
# 49  2440   46     2               35              20         4.0          1.0
#
#     Gender  SubscriberJoinDate  LastSatisfactionSurveyScore  Churn
# 0      1.0                  11                            1      0
# 1      1.0                  11                            4      0
# 2      2.0                  40                            5      0
# 3      1.0                  50                            1      0
# 4      2.0                  20                            2      0
# 5      1.0                  40                            3      0
# 6      1.0                  20                            1      0
# 7      2.0                  50                            4      0
# 8      2.0                  30                            4      0
# 9      2.0                  20                            5      0
# 10     1.0                  30                            5      0
# 11     1.0                  40                            2      0
# 12     1.0                  50                            4      0
# 13     1.0                  50                            1      0
# 14     1.0                  30                            3      0
# 15     1.0                  50                            5      0
# 16     1.0                  40                            4      0
# 17     1.0                  11                            5      0
# 18     2.0                  30                            4      0
# 19     1.0                  40                            1      0
# 20     1.0                  40                            2      0
# 21     2.0                  20                            3      0
# 22     1.0                  11                            3      0
# 23     1.0                  50                            1      0
# 24     1.0                  40                            4      0
# 25     1.0                  30                            5      0
# 26     1.0                  11                            3      0
# 27     1.0                  40                            2      0
# 28     0.0                  40                            4      0
# 29     1.0                  40                            2      0
# 30     2.0                  20                            3      0
# 31     1.0                  40                            4      0
# 32     2.0                  20                            2      0
# 33     1.0                  50                            5      0
# 34     1.0                  11                            3      0
# 35     1.0                  11                            1      0
# 36     2.0                  11                            1      0
# 37     1.0                  50                            4      0
# 38     2.0                  40                            2      0
# 39     1.0                  50                            3      0
# 40     2.0                  50                            5      0
# 41     2.0                  50                            2      0
# 42     2.0                  20                            2      0
# 43     2.0                  30                            3      0
# 44     1.0                  40                            2      0
# 45     2.0                  20                            5      1
# 46     1.0                  30                            1      0
# 47     1.0                  40                            3      0
# 48     2.0                  20                            3      0
# 49     1.0                  11                            3      0

# %%
# print df1.columns
df1['Occupation'] = df1['Occupation'].astype(np.int64)
df1['IncomeLevel'] = df1['IncomeLevel'].astype(np.int64)
df1['Gender'] = df1['Gender'].astype(np.int64)
df1['Churn'] = df1['Churn'].astype(np.int64)
print df1.dtypes
# Out:
# ID                             int64
# AGE                            int64
# Plan                           int64
# LastMonthlyBill                int64
# LastpaidAmount                 int64
# Occupation                     int64
# IncomeLevel                    int64
# Gender                         int64
# SubscriberJoinDate             int64
# LastSatisfactionSurveyScore    int64
# Churn                          int64
# dtype: object

# %%
df1.head(50)
# Out:
#       ID  AGE  Plan  LastMonthlyBill  LastpaidAmount  Occupation  IncomeLevel  \
# 0     19   43     1               41              20           0            1
# 1     88   95     1               32              20           0            3
# 2    130   64     4               60              20           0            2
# 3    227   98     2               37              20           1            1
# 4    294   33     2               66              20           5            3
# 5    394   60     4               50              20           8            2
# 6    423   32     4               56              20           3            1
# 7    438   84     2              101              20           2            2
# 8    669   23     2              132              20           7            1
# 9    726   84     4               81              20           8            1
# 10   844   66     5               31              20           7            2
# 11   897   62     2              129              20           3            1
# 12   907   35     5               39              20           1            3
# 13   919   15     6               94              20           8            1
# 14   990   68     4               52              20           5            3
# 15  1000   32     1               45              20           2            1
# 16  1007   42     6               41              20           6            3
# 17  1055   95     4               36              20           7            2
# 18  1179   37     4               36              20           3            2
# 19  1265   82     3               36              20           3            1
# 20  1289   20     3               42              20           4            2
# 21  1321   33     5               30              20           5            3
# 22  1332   22     5              128              20           5            2
# 23  1357   96     6              126              20           6            3
# 24  1366   97     4               36              20           7            1
# 25  1369   33     6              126              20           8            2
# 26  1399   96     2              109              20           3            1
# 27  1409   48     4               47              20           6            1
# 28  1439   48     6               96              20           2            3
# 29  1459   96     2               30              20           7            2
# 30  1521   39     3               89              20           1            2
# 31  1526   32     5               35              20           2            1
# 32  1536   58     5               87              20           3            1
# 33  1550   92     4               34              20           4            1
# 34  1596   67     4               36              20           4            1
# 35  1653   96     4               77              20           7            1
# 36  1781   90     4               31              20           3            1
# 37  1800   76     1               60              20           4            2
# 38  1816   80     1               50              20           2            1
# 39  1856   54     6               60              20           4            2
# 40  1916   94     2               42              20           2            3
# 41  1949   59     1               32              20           2            2
# 42  1997   75     3               45              20           4            3
# 43  2077   62     4              119              20           4            1
# 44  2202   60     2              125              20           5            3
# 45  2223   94     1               33              20           1            3
# 46  2243   63     4               94              20           8            3
# 47  2261   16     1               37              20           8            2
# 48  2424   40     6               31              20           2            2
# 49  2440   46     2               35              20           4            1
#
#     Gender  SubscriberJoinDate  LastSatisfactionSurveyScore  Churn
# 0        1                  11                            1      0
# 1        1                  11                            4      0
# 2        2                  40                            5      0
# 3        1                  50                            1      0
# 4        2                  20                            2      0
# 5        1                  40                            3      0
# 6        1                  20                            1      0
# 7        2                  50                            4      0
# 8        2                  30                            4      0
# 9        2                  20                            5      0
# 10       1                  30                            5      0
# 11       1                  40                            2      0
# 12       1                  50                            4      0
# 13       1                  50                            1      0
# 14       1                  30                            3      0
# 15       1                  50                            5      0
# 16       1                  40                            4      0
# 17       1                  11                            5      0
# 18       2                  30                            4      0
# 19       1                  40                            1      0
# 20       1                  40                            2      0
# 21       2                  20                            3      0
# 22       1                  11                            3      0
# 23       1                  50                            1      0
# 24       1                  40                            4      0
# 25       1                  30                            5      0
# 26       1                  11                            3      0
# 27       1                  40                            2      0
# 28       0                  40                            4      0
# 29       1                  40                            2      0
# 30       2                  20                            3      0
# 31       1                  40                            4      0
# 32       2                  20                            2      0
# 33       1                  50                            5      0
# 34       1                  11                            3      0
# 35       1                  11                            1      0
# 36       2                  11                            1      0
# 37       1                  50                            4      0
# 38       2                  40                            2      0
# 39       1                  50                            3      0
# 40       2                  50                            5      0
# 41       2                  50                            2      0
# 42       2                  20                            2      0
# 43       2                  30                            3      0
# 44       1                  40                            2      0
# 45       2                  20                            5      1
# 46       1                  30                            1      0
# 47       1                  40                            3      0
# 48       2                  20                            3      0
# 49       1                  11                            3      0

# %%
print("Number of rows: ", df.shape[0])
counts = df1.describe().iloc[0]
display(
    pd.DataFrame(
        counts.tolist(), 
        columns=["Count of values"], 
        index=counts.index.values
    ).transpose()
)
# Out:
# ('Number of rows: ', 9789)
#                      ID     AGE    Plan  LastMonthlyBill  LastpaidAmount  \
# Count of values  9789.0  9789.0  9789.0           9789.0          9789.0
#
#                  Occupation  IncomeLevel  Gender  SubscriberJoinDate  \
# Count of values      9789.0       9789.0  9789.0              9789.0
#
#                  LastSatisfactionSurveyScore   Churn
# Count of values                       9789.0  9789.0

# %%
df1['AGE'].fillna(0, inplace=True)
df1['LastSatisfactionSurveyScore'].fillna(0, inplace=True)
df1['Churn'].fillna(0, inplace=True)
df1.head(40)
# Out:
#       ID  AGE  Plan  LastMonthlyBill  LastpaidAmount  Occupation  IncomeLevel  \
# 0     19   43     1               41              20           0            1
# 1     88   95     1               32              20           0            3
# 2    130   64     4               60              20           0            2
# 3    227   98     2               37              20           1            1
# 4    294   33     2               66              20           5            3
# 5    394   60     4               50              20           8            2
# 6    423   32     4               56              20           3            1
# 7    438   84     2              101              20           2            2
# 8    669   23     2              132              20           7            1
# 9    726   84     4               81              20           8            1
# 10   844   66     5               31              20           7            2
# 11   897   62     2              129              20           3            1
# 12   907   35     5               39              20           1            3
# 13   919   15     6               94              20           8            1
# 14   990   68     4               52              20           5            3
# 15  1000   32     1               45              20           2            1
# 16  1007   42     6               41              20           6            3
# 17  1055   95     4               36              20           7            2
# 18  1179   37     4               36              20           3            2
# 19  1265   82     3               36              20           3            1
# 20  1289   20     3               42              20           4            2
# 21  1321   33     5               30              20           5            3
# 22  1332   22     5              128              20           5            2
# 23  1357   96     6              126              20           6            3
# 24  1366   97     4               36              20           7            1
# 25  1369   33     6              126              20           8            2
# 26  1399   96     2              109              20           3            1
# 27  1409   48     4               47              20           6            1
# 28  1439   48     6               96              20           2            3
# 29  1459   96     2               30              20           7            2
# 30  1521   39     3               89              20           1            2
# 31  1526   32     5               35              20           2            1
# 32  1536   58     5               87              20           3            1
# 33  1550   92     4               34              20           4            1
# 34  1596   67     4               36              20           4            1
# 35  1653   96     4               77              20           7            1
# 36  1781   90     4               31              20           3            1
# 37  1800   76     1               60              20           4            2
# 38  1816   80     1               50              20           2            1
# 39  1856   54     6               60              20           4            2
#
#     Gender  SubscriberJoinDate  LastSatisfactionSurveyScore  Churn
# 0        1                  11                            1      0
# 1        1                  11                            4      0
# 2        2                  40                            5      0
# 3        1                  50                            1      0
# 4        2                  20                            2      0
# 5        1                  40                            3      0
# 6        1                  20                            1      0
# 7        2                  50                            4      0
# 8        2                  30                            4      0
# 9        2                  20                            5      0
# 10       1                  30                            5      0
# 11       1                  40                            2      0
# 12       1                  50                            4      0
# 13       1                  50                            1      0
# 14       1                  30                            3      0
# 15       1                  50                            5      0
# 16       1                  40                            4      0
# 17       1                  11                            5      0
# 18       2                  30                            4      0
# 19       1                  40                            1      0
# 20       1                  40                            2      0
# 21       2                  20                            3      0
# 22       1                  11                            3      0
# 23       1                  50                            1      0
# 24       1                  40                            4      0
# 25       1                  30                            5      0
# 26       1                  11                            3      0
# 27       1                  40                            2      0
# 28       0                  40                            4      0
# 29       1                  40                            2      0
# 30       2                  20                            3      0
# 31       1                  40                            4      0
# 32       2                  20                            2      0
# 33       1                  50                            5      0
# 34       1                  11                            3      0
# 35       1                  11                            1      0
# 36       2                  11                            1      0
# 37       1                  50                            4      0
# 38       2                  40                            2      0
# 39       1                  50                            3      0

# %%
print("Number of rows: ", df.shape[0])
counts = df1.describe().iloc[0]
display(
    pd.DataFrame(
        counts.tolist(), 
        columns=["Count of values"], 
        index=counts.index.values
    ).transpose()
)
# Out:
# ('Number of rows: ', 9789)
#                      ID     AGE    Plan  LastMonthlyBill  LastpaidAmount  \
# Count of values  9789.0  9789.0  9789.0           9789.0          9789.0
#
#                  Occupation  IncomeLevel  Gender  SubscriberJoinDate  \
# Count of values      9789.0       9789.0  9789.0              9789.0
#
#                  LastSatisfactionSurveyScore   Churn
# Count of values                       9789.0  9789.0

# %%
# here i drop the ID column .and I chose feature as [AGE,Plan,LastMonthlyBill,LastpaidAmount,Occupation,IncomeLevel,Gender,SubscriberJoinDate,
#LastSatisfactionSurveyScore]
df1 = df1.drop(["ID"], axis=1)
features = df1.drop(["Churn"], axis=1).columns

# %%
# I only take train and test data .and i splited train(75%) and test(25%)
train, test = train_test_split(df1, test_size=0.25)

# %%
#we use RandomForestClassifier .First we initialise our model,
#fit it to our dataset using the fit() method, then simply make our predictions using the predict() method.
clf = RandomForestClassifier(n_estimators=30)
clf.fit(train[features], train["Churn"])

# Make predictions
predictions = clf.predict(test[features])
probs = clf.predict_proba(test[features])
display(predictions)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
score = clf.score(test[features], test["Churn"])
print("Accuracy: ", score)
# Out:
# ('Accuracy: ', 0.83864379084967322)

# %%
# now make confusion_matrix and a ROC curve to check  into the quality of our results.
get_ipython().magic('matplotlib inline')
confusion_matrix = pd.DataFrame(
    confusion_matrix(test["Churn"], predictions), 
    columns=["Predicted False", "Predicted True"], 
    index=["Actual False", "Actual True"]
)
display(confusion_matrix)

# Calculate the fpr and tpr for all thresholds of the classification
fpr, tpr, threshold = roc_curve(test["Churn"], probs[:,1])
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
#               Predicted False  Predicted True
# Actual False             2053               4
# Actual True               391               0

# %%
#now I check which is most dependent  feature to predict the churn .
fig = plt.figure(figsize=(20, 18))
ax = fig.add_subplot(111)

f = pd.DataFrame(clf.feature_importances_, columns=["importance"])
f["labels"] = features
f.sort_values("importance", inplace=True, ascending=False)
display(f.head(5))

index = np.arange(len(clf.feature_importances_))
bar_width = 0.5
rects = plt.barh(index , f["importance"], bar_width, alpha=0.4, color='b', label='Main')
plt.yticks(index, f["labels"])
plt.show()
# Out:
#    importance           labels
# 2    0.198638  LastMonthlyBill
# 0    0.198457              AGE
# 3    0.187684   LastpaidAmount
# 4    0.101033       Occupation
# 1    0.081709             Plan

# %%
#we can choose support vector machine and 
#a neural network alongside our random forest and then select the best performing of them to refine.
